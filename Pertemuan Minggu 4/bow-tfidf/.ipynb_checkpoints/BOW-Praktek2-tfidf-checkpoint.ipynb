# %% [markdown]
# Praktek TF-IDF
# =============================
#
# **Modul untuk Pembelajaran Analitika Media Sosial**
#
# **Author:** *Dr. Eng. Farrikh Alzami, M.Kom*, *Abu Salam, M.Kom*
#
# Program Studi Sistem Informasi S1
#
# ***Universitas Dian Nuswantoro 2021***

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('clean_dataset_stem.csv',sep=';')

# %%
dataset_feature = dataset['ProcessedText'].astype(str)

# %%
dataset.shape
# Out:
# (902, 10)

# %%
dataset_label = dataset['Sentimen']

# %% [markdown]
# # cek distribusi label

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Visualizing the target variable
plt.figure(figsize=(12,8))
sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')
plt.legend(loc='best')
plt.show()
# Out:
# /Users/masaboe/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
dataset_label.value_counts()
# Out:
#  1.0    441
#  0.0    266
# -1.0    195
# Name: Sentimen, dtype: int64

# %% [markdown]
# # TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
X = vectorizer.fit_transform(dataset_feature)

# %%
print(X
# Out:
#   (0, 2144)	0.4481550178120987
#   (0, 1144)	0.29015492211310023
#   (0, 1199)	0.4029863331954986
#   (0, 2921)	0.26402429338395356
#   (0, 1659)	0.35480026943720133
#   (0, 647)	0.07695154876904603
#   (0, 2815)	0.3750645207138148
#   (0, 2046)	0.3750645207138148
#   (0, 581)	0.26402429338395356
#   (1, 700)	0.3652944872942696
#   (1, 2801)	0.40844300790270155
#   (1, 1192)	0.35532001456771856
#   (1, 3750)	0.256406436357373
#   (1, 2193)	0.2598634623547684
#   (1, 3826)	0.46750170514503614
#   (1, 2196)	0.35532001456771856
#   (1, 76)	0.30036264159268933
#   (1, 647)	0.07197764161496706
#   (2, 2439)	0.35442886639185
#   (2, 697)	0.37223498359276097
#   (2, 3411)	0.41513741344994337
#   (2, 1358)	0.22288618996237033
#   (2, 3285)	0.37223498359276097
#   (2, 2269)	0.33471813359909164
#   (2, 2520)	0.33471813359909164
#   :	:
#   (901, 2638)	0.190858642828711
#   (901, 1864)	0.190858642828711
#   (901, 822)	0.190858642828711
#   (901, 1027)	0.190858642828711
#   (901, 1793)	0.5725759284861329
#   (901, 492)	0.190858642828711
#   (901, 83)	0.190858642828711
#   (901, 313)	0.166270923703876
#   (901, 2034)	0.14511348159061443
#   (901, 2273)	0.15365885984515915
#   (901, 1792)	0.1799784037885396
#   (901, 1348)	0.166270923703876
#   (901, 855)	0.15724203739131243
#   (901, 3060)	0.12907114072032413
#   (901, 3346)	0.14277862080498777
#   (901, 658)	0.1386421458995365
#   (901, 3622)	0.14277862080498777
#   (901, 2271)	0.2701179367067664
#   (901, 523)	0.10980864837304397
#   (901, 676)	0.277284291799073
#   (901, 3379)	0.10731066263998133
#   (901, 1374)	0.11731102051833439
#   (901, 1376)	0.15049827325659226
#   (901, 2445)	0.09623238601301264
#   (901, 647)	0.027709890474744675

# %%
print(X.shape)
# Out:
# (902, 3867)

# %%
print(vectorizer.get_feature_names())
# Out:
# ['aa', 'aamiin', 'aamiingimana', 'aamiinmulut', 'aau', 'abai', 'abang', 'abdul', 'abdullah', 'abi', 'abis', 'abyasa', 'acah', 'acara', 'ace', 'aceh', 'achmad', 'actmalang', 'ad', 'ada', 'adab', 'adakan', 'adalah', 'adidaya', 'adik', 'adil', 'adiluntuk', 'adiwinata', 'admin', 'adminsitus', 'adminstrasi', 'adoiii', 'adoilah', 'adsemoga', 'adun', 'adzan', 'ae', 'afau', 'afiat', 'afifi', 'afriandi', 'afs', 'agak', 'agama', 'agar', 'agung', 'ah', 'ahli', 'aidilfitri', 'aing', 'aiptu', 'air', 'aj', 'aja', 'ajaaa', 'ajah', 'ajak', 'ajar', 'aji', 'ajig', 'ak', 'akad', 'akak', 'akan', 'akbar', 'akh', 'akhir', 'akhirat', 'akhlak', 'akibat', 'akn', 'akses', 'aksesoris', 'aksi', 'aktif', 'aktivitas', 'aku', 'akuautocorrect', 'akun', 'akur', 'akurat', 'akutu', 'ala', 'alaaaa', 'alam', 'alami', 'alamiah', 'alamiin', 'alamin', 'alas', 'alat', 'album', 'alergi', 'alhamdulilah', 'alhamdulillah', 'aliansi', 'alih', 'alir', 'all', 'allaah', 'allah', 'allahh', 'allahu', 'allhumma', 'alloh', 'almasih', 'alokasi', 'alor', 'alpenland', 'alternatif', 'alumni', 'alun', 'aluwi', 'am', 'ama', 'amal', 'aman', 'ambal', 'ambil', 'ambisi', 'ambulans', 'amerika', 'amiiin', 'amiin', 'amin', 'aminnn', 'amit', 'amp', 'ampe', 'ampi', 'ampun', 'amuk', 'an', 'anak', 'analisis', 'anamnesis', 'anarko', 'anas', 'ancam', 'anchor', 'and', 'anda', 'anderson', 'andes', 'andi', 'aneh', 'anget', 'anggap', 'anggar', 'anggota', 'angka', 'angkara', 'angkasa', 'angkat', 'angkuh', 'anies', 'anis', 'anjing', 'anjir', 'anjirr', 'anjlokk', 'anjur', 'anom', 'anomali', 'ansor', 'antar', 'antara', 'antibodi', 'antisepti', 'antiseptic', 'antisipasi', 'antokkan', 'antologi', 'antri', 'anyar', 'anying', 'ap', 'apa', 'apaa', 'apabila', 'apakah', 'aparat', 'aparatur', 'apart', 'apd', 'api', 'apit', 'aplikasi', 'apm', 'apotek', 'apple', 'apresiasi', 'april', 'aprildalam', 'arah', 'area', 'argopuro', 'arif', 'arini', 'army', 'arti', 'artikel', 'artis', 'arus', 'arya', 'as', 'asa', 'asal', 'asalamualaikum', 'asamau', 'asb', 'asih', 'asik', 'asimilasi', 'asli', 'asmara', 'asn', 'asrama', 'assalam', 'assignment', 'astagfirullah', 'asupan', 'asyir', 'at', 'atas', 'atau', 'atlet', 'atlit', 'ato', 'attaqwa', 'atur', 'aulia', 'aurat', 'awak', 'awal', 'awam', 'aware', 'awas', 'awat', 'away', 'awda', 'ayo', 'ayok', 'azab', 'azali', 'azis', 'azmi', 'baasyir', 'babel', 'babinsa', 'baby', 'baca', 'bacot', 'badai', 'badan', 'badminton', 'badung', 'bae', 'bagai', 'bagaimana', 'bagi', 'bagiin', 'bagus', 'bagusnye', 'bahagia', 'bahan', 'baharu', 'bahas', 'bahaya', 'bahgia', 'bahkan', 'bahu', 'bahwa', 'baik', 'bain', 'bait', 'bakal', 'bakornas', 'bakti', 'bal', 'bala', 'balai', 'balas', 'balik', 'balikpapan', 'bambanglipuro', 'bandar', 'bandara', 'banding', 'bandung', 'bang', 'banget', 'bangka', 'bangkai', 'bangsa', 'bangun', 'banjarnegara', 'banjir', 'banten', 'banteng', 'banteras', 'bantu', 'bantuin', 'bantul', 'banyak', 'banyakk', 'banyudonosaya', 'bapak', 'bara', 'barang', 'barangan', 'barashi', 'barat', 'barber', 'bareng', 'baru', 'barusan', 'bas', 'bash', 'basi', 'basmi', 'basri', 'basuh', 'batal', 'batall', 'batas', 'batola', 'batu', 'batuk', 'bau', 'bawa', 'bawah', 'bawain', 'bawak', 'bawaslu', 'baya', 'bayan', 'bayang', 'bayangin', 'bayar', 'bayarreal', 'bayi', 'bazar', 'baznas', 'be', 'bea', 'beast', 'bebal', 'beban', 'bebas', 'beberapa', 'becak', 'beda', 'been', 'before', 'begini', 'begins', 'begitu', 'begooooo', 'bekas', 'bekerjasama', 'bela', 'belah', 'belakang', 'belanja', 'belawan', 'bele', 'beli', 'belia', 'beliau', 'believe', 'belitung', 'belok', 'belum', 'bem', 'benar', 'benard', 'bencana', 'benci', 'benda', 'bener', 'beneran', 'bengese', 'bengkulu', 'benjol', 'bentuk', 'ber', 'beraktifitas', 'berani', 'beransur', 'beranta', 'berantas', 'berapa', 'beras', 'berat', 'berdzikir', 'beres', 'beri', 'berita', 'beritamedia', 'berkah', 'berkat', 'berkatifitas', 'berlanjutsampe', 'bernardino', 'berprilaku', 'bersih', 'bersin', 'besar', 'besarisi', 'besok', 'besor', 'betapa', 'bete', 'betoi', 'bette ...
