# %% [markdown]
# Praktek TF-IDF
# =============================

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('clean_dataset_stem.csv',sep=';')

# %%
dataset.shape
# Out:
# (902, 10)

# %%
dataset.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
#
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
#
#                                               step01  \
# 0  cegah mata rantai covid   mari kita dirumah sa...
# 1  aku mohon yaallah semoga wabah covid   menghil...
# 2  pemprov papua naikkan status jadi tanggap daru...
#
#                                               tokens  \
# 0  ['cegah', 'mata', 'rantai', 'covid', 'mari', '...
# 1  ['aku', 'mohon', 'yaallah', 'semoga', 'wabah',...
# 2  ['pemprov', 'papua', 'naikkan', 'status', 'jad...
#
#                                         final_tokens  \
# 0  ['cegah', 'mata', 'rantai', 'covid', 'mari', '...
# 1  ['aku', 'mohon', 'yaallah', 'semoga', 'wabah',...
# 2  ['pemprov', 'papua', 'naikkan', 'status', 'jad...
#
#                                               step02  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
#
#                                        finalText_str  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
#
#                                        ProcessedText
# 0  cegah mata rantai covid kita rumah hingga hari...
# 1  aku mohon yaallah moga wabah covid hilang rama...
# 2  pemprov papua naik status jadi tanggap darurat...

# %%
dataset_feature = dataset['ProcessedText'].astype(str)

# %%
dataset_feature
# Out:
# 0      cegah mata rantai covid kita rumah hingga hari...
# 1      aku mohon yaallah moga wabah covid hilang rama...
# 2      pemprov papua naik status jadi tanggap darurat...
# 3                      covid nyampe prigen mbak hmm hoax
# 4      nyuruh orang pintar lu aja togog kerumun orang...
#                              ...
# 897    seluruh negara dunia alami masa sulit covid ra...
# 898    covid skripsi disaster selesai mau bgt bljr ma...
# 899    malam projek benda bincang malam fb satu belia...
# 900                          pontang panting koyak covid
# 901    masalah sekarang isu jangkit covid alaaaa bosa...
# Name: ProcessedText, Length: 902, dtype: object

# %%
dataset_label = dataset['Sentimen']

# %%
dataset_label
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      0.0
# 4     -1.0
#       ...
# 897    1.0
# 898    1.0
# 899    0.0
# 900   -1.0
# 901   -1.0
# Name: Sentimen, Length: 902, dtype: float64

# %% [markdown]
# # cek distribusi label

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Visualizing the target variable
plt.figure(figsize=(12,8))
sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_14416\1470841120.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')

# %%
dataset_label.value_counts()
# Out:
# Sentimen
#  1.0    441
#  0.0    266
# -1.0    195
# Name: count, dtype: int64

# %% [markdown]
# # TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
positive_reviews = dataset[(dataset["Sentimen"] == 1)]
negative_reviews = dataset[(dataset["Sentimen"] == -1)]
neutral_reviews = dataset[(dataset["Sentimen"] == 0)]

# %%
positive_reviews.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 6             6           6
# 7             7           7
#
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 6  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 7  Hikmah di balik musibah covid-19, smg para pej...       1.0
#
#                                               step01  \
# 0  cegah mata rantai covid   mari kita dirumah sa...
# 1  aku mohon yaallah semoga wabah covid   menghil...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 6  selamat pagi hari jumat jumat keempat di kala ...
# 7  hikmah di balik musibah covid   smg para pejab...
#
#                                               tokens  \
# 0  ['cegah', 'mata', 'rantai', 'covid', 'mari', '...
# 1  ['aku', 'mohon', 'yaallah', 'semoga', 'wabah',...
# 2  ['pemprov', 'papua', 'naikkan', 'status', 'jad...
# 6  ['selamat', 'pagi', 'hari', 'jumat', 'jumat', ...
# 7  ['hikmah', 'di', 'balik', 'musibah', 'covid', ...
#
#                                         final_tokens  \
# 0  ['cegah', 'mata', 'rantai', 'covid', 'mari', '...
# 1  ['aku', 'mohon', 'yaallah', 'semoga', 'wabah',...
# 2  ['pemprov', 'papua', 'naikkan', 'status', 'jad...
# 6  ['selamat', 'pagi', 'hari', 'jumat', 'jumat', ...
# 7  ['hikmah', 'di', 'balik', 'musibah', 'covid', ...
#
#                                               step02  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 6  selamat pagi hari jumat jumat keempat di kala ...
# 7  hikmah di balik musibah covid smg para pejabat...
#
#                                        finalText_str  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 6  selamat pagi hari jumat jumat keempat di kala ...
# 7  hikmah di balik musibah covid smg para pejabat...
#
#                                        ProcessedText
# 0  cegah mata rantai covid kita rumah hingga hari...
# 1  aku mohon yaallah moga wabah covid hilang rama...
# 2  pemprov papua naik status jadi tanggap darurat...
# 6  selamat pagi hari jumat jumat empat kala pande...
# 7  hikmah balik musibah covid smg jabat perintah ...

# %%
Positive_tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
Positive_tf_idf = Positive_tf_idf_vect.fit_transform(positive_reviews["ProcessedText"].values)

# %%
Positive_tf_idf.shape
# Out:
# (441, 7781)

# %%
features = Positive_tf_idf_vect.get_feature_names_out()

# %%
idfValues = Positive_tf_idf_vect.idf_

# %%
d = dict(zip(features, 9 - idfValues))

# %%
sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)

# %%
for i in range(200):
    print(sortedDict[i])
# Out:
# ('covid', 7.97247532660991)
# ('virus', 6.083077387817939)
# ('cegah', 6.067573201281974)
# ('sebar', 6.0195639820956135)
# ('corona', 5.934041808657451)
# ('moga', 5.878982031474424)
# ('sama', 5.878982031474424)
# ('rumah', 5.737331514411396)
# ('yg', 5.737331514411396)
# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plot

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)

# %% [markdown]
# # silakan lakukan untuk netral dan negative

# %% [markdown]
# ## Netral

# %%
Neutral_tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
Neutral_tf_idf = Neutral_tf_idf_vect.fit_transform(neutral_reviews["ProcessedText"].values)

# %%
Neutral_tf_idf.shape
# Out:
# (266, 5154)

# %%
features = Neutral_tf_idf_vect.get_feature_names_out()

# %%
idfValues = Neutral_tf_idf_vect.idf_

# %%
d = dict(zip(features, 9 - idfValues))

# %%
sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)

# %%
for i in range(200):
    print(sortedDict[i])
# Out:
# ('covid', 7.96182742649497)
# ('yg', 6.101630795713687)
# ('orang', 5.5908051719476966)
# ('positif', 5.5482455575289)
# ('date', 5.408483615153742)
# ('hari', 5.408483615153742)
# ('indonesia', 5.3571903207661915)
# ('ni', 5.3571903207661915)
# ('ada', 5.303123099495915)
# ('mau', 5.303123099495915)
# ('pasien', 5.303123099495915)
# ('baru', 5.2459646856559665)
# ('jadi', 5.2459646856559665)
# ('virus', 5.2459646856559665)
# ('banyak', 5.185340063839531)
# ('lebih', 5.185340063839531)
# ('kasus', 5.12080154270196)
# ('positif covid', 5.12080154270196)
# ('tinggal', 5.12080154270196)
# ('kena', 5.051808671215009)
# ('pandemi', 5.051808671215009)
# ('update', 5.051808671215009)
# ('apa', 4.9777006990612875)
# ('rumah', 4.9777006990612875)
# ('buat', 4.897657991387751)
# ('bukan', 4.897657991387751)
# ('dgn', 4.897657991387751)
# ('di', 4.897657991387751)
# ('ga', 4.897657991387751)
# ('kalo', 4.897657991387751)
# ('pandemi covid', 4.897657991387751)
# ('sakit', 4.897657991387751)
# ('sebar', 4.897657991387751)
# ('tak', 4.897657991387751)
# ('tambah', 4.897657991387751)
# ('warga', 4.897657991387751)
# ('aku', 4.810646614398121)
# ('bagaimana', 4.810646614398121)
# ('ikut', 4.810646614398121)
# ('negara', 4.810646614398121)
# ('nya', 4.810646614398121)
# ('udah', 4.810646614398121)
# ('baik', 4.715336434593796)
# ('covid ni', 4.715336434593796)
# ('ini', 4.715336434593796)
# ('org', 4.715336434593796)
# ('perintah', 4.715336434593796)
# ('salah', 4.715336434593796)
# ('satu', 4.715336434593796)
# ('tanggal', 4.715336434593796)
# ('wabah', 4.715336434593796)
# ('corona', 4.6099759189359695)
# ('dunia', 4.6099759189359695)
# ('gak', 4.6099759189359695)
# ('jalan', 4.6099759189359695)
# ('jumlah', 4.6099759189359695)
# ('kerja', 4.6099759189359695)
# ('mati', 4.6099759189359695)
# ('padahal', 4.6099759189359695)
# ('psbb', 4.6099759189359695)
# ('tu', 4.204510810827806)
# ('tular', 4.204510810827806)
# ('video', 4.204510810827806)
# ('ya', 4.204510810827806)
# ('akhir', 4.022189254033851)
# ('balik', 4.022189254033851)
# ('batas', 4.022189254033851)
# ('beberapa', 4.022189254033851)
# ('beli', 4.022189254033851)
# ('belum', 4.022189254033851)
# ('benar', 4.022189254033851)
# ('berapa', 4.022189254033851)
# ('beri', 4.022189254033851)
# ('besar', 4.022189254033851)
# ('bilang', 4.022189254033851)
# ('cegah', 4.022189254033851)
# ('covid hari', 4.022189254033851)
# ('covid kabupaten', 4.022189254033851)
# ('covid kalo', 4.022189254033851)
# ('cuma', 4.022189254033851)
# ('dampak covid', 4.022189254033851)
# ('dari', 4.022189254033851)
# ('diri', 4.022189254033851)
# ('dlm', 4.022189254033851)
# ('dokter', 4.022189254033851)
# ('gaji', 4.022189254033851)
# ('gejala', 4.022189254033851)
# ('gin', 4.022189254033851)
# ('gugus tugas', 4.022189254033851)
# ('hati', 4.022189254033851)
# ('hilang', 4.022189254033851)
# ('hingga', 4.022189254033851)
# ('ibu', 4.022189254033851)
# ('jangan', 4.022189254033851)
# ('jd', 4.022189254033851)
# ('jg', 4.022189254033851)
# ('kasus positif', 4.022189254033851)
# ('kek', 4.022189254033851)
# ('kontak', 4.022189254033851)
# ('korban', 4.022189254033851)
# ('la', 4.022189254033851)
# ('langsung', 4.022189254033851)
# ('lebih baik', 4.022189254033851)
# ('lepas', 4.022189254033851)
# ('malah', 4.022189254033851)
# ('masker', 4.022189254033851)
# ('masyarakat', 4.022189254033851)

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)

# %% [markdown]
# ## Negative

# %%
Negative_tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
Negative_tf_idf = Negative_tf_idf_vect.fit_transform(negative_reviews["ProcessedText"].values)

# %%
Negative_tf_idf.shape
# Out:
# (195, 4174)

# %%
features = Negative_tf_idf_vect.get_feature_names_out()

# %%
idfValues = Negative_tf_idf_vect.idf_

# %%
d = dict(zip(features, 9 - idfValues))

# %%
sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)

# %%
for i in range(200):
    print(sortedDict[i])
# Out:
# ('covid', 7.963632355829125)
# ('yg', 6.593086351677374)
# ('jadi', 5.940761165637683)
# ('orang', 5.8999391711174285)
# ('semua', 5.717617614323474)
# ('bukan', 5.666324319935923)
# ('kena', 5.612257098665648)
# ('jenazah', 5.555098684825699)
# ('mau', 5.555098684825699)
# ('sama', 5.494474063009264)
# ('tinggal', 5.494474063009264)
# ('virus', 5.494474063009264)
# ('mati', 5.360942670384741)
# ('rumah', 5.360942670384741)
# ('tolak', 5.360942670384741)
# ('aja', 5.2868346982310195)
# ('apa', 5.2868346982310195)
# ('buat', 5.2868346982310195)
# ('ga', 5.2868346982310195)
# ('kalo', 5.206791990557483)
# ('lebih', 5.206791990557483)
# ('duit', 4.331323253203584)
# ('dulu', 4.331323253203584)
# ('emang', 4.331323253203584)
# ('gue', 4.331323253203584)
# ('hidup', 4.331323253203584)
# ('hubung', 4.331323253203584)
# ('indigo', 4.331323253203584)
# ('isi', 4.331323253203584)
# ('isolasi', 4.331323253203584)
# ('jauh', 4.331323253203584)
# ('jenazah covid', 4.331323253203584)
# ('jg', 4.331323253203584)
# ('jgn', 4.331323253203584)
# ('kalian', 4.331323253203584)
# ('kaya', 4.331323253203584)
# ('keluarga', 4.331323253203584)
# ('ken', 4.331323253203584)
# ('klo', 4.331323253203584)
# ('krn', 4.331323253203584)
# ('la', 4.331323253203584)
# ('laku', 4.331323253203584)
# ('makam', 4.331323253203584)
# ('makin', 4.331323253203584)
# ('manusia', 4.331323253203584)
# ('moga', 4.331323253203584)
# ('mudah', 4.331323253203584)
# ('nak', 4.331323253203584)
# ('nolak jenazah', 4.331323253203584)
# ('ojol', 4.331323253203584)
# ('online', 4.331323253203584)
# ('org', 4.331323253203584)
# ('pergi', 4.331323253203584)
# ('pernah', 4.331323253203584)
# ('rasa', 4.331323253203584)
# ('saat', 4.331323253203584)
# ('sakit', 4.331323253203584)
# ('sampe', 4.331323253203584)
# ('sebar', 4.331323253203584)
# ('sehat', 4.331323253203584)
# ('si', 4.331323253203584)
# ('siapa', 4.331323253203584)
# ('sini', 4.331323253203584)
# ('skrg', 4.331323253203584)
# ('sok', 4.331323253203584)
# ('takut', 4.331323253203584)
# ('tempat', 4.331323253203584)
# ('tengah wabah', 4.331323253203584)
# ('terus', 4.331323253203584)
# ('tolak warga', 4.331323253203584)
# ('tu', 4.331323253203584)
# ('utk', 4.331323253203584)
# ('agama', 4.108179701889373)
# ('agama islam', 4.108179701889373)
# ('air', 4.108179701889373)
# ('ajar', 4.108179701889373)
# ('akan', 4.108179701889373)
# ('anggap', 4.108179701889373)
# ('apa yg', 4.108179701889373)
# ('asa', 4.108179701889373)
# ('bagai', 4.108179701889373)
# ('bagaimana', 4.108179701889373)
# ('baik', 4.108179701889373)
# ('beban', 4.108179701889373)
# ('bebas tengah', 4.108179701889373)
# ('beberapa', 4.108179701889373)
# ('beli', 4.108179701889373)
# ('berat', 4.108179701889373)
# ('berita covid', 4.108179701889373)
# ('besar', 4.108179701889373)
# ('biasa', 4.108179701889373)
# ('biaya', 4.108179701889373)
# ('biji', 4.108179701889373)
# ('bila', 4.108179701889373)
# ('bilang', 4.108179701889373)
# ('bisa', 4.108179701889373)
# ('bodoh', 4.108179701889373)
# ('bom', 4.108179701889373)
# ('bukan cuma', 4.108179701889373)
# ('cara', 4.108179701889373)
# ('cegah', 4.108179701889373)
# ('coba', 4.108179701889373)
# ('covid masuk', 4.108179701889373)
# ('covid tolak', 4.108179701889373)
# ('daerah', 4.108179701889373)
# ('dan', 4.108179701889373)

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)
